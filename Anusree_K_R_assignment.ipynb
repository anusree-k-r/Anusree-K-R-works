# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
### reading dataset

# %%
data = pd.read_excel("/content/iris.xls")

# %%
data.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %%
pd.read_excel('iris.xls')
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
### reading columns

data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
### mean of each column

SL_mean_data = data["SL"].mean()
SW_mean_data = data["SW"].mean()
PL_mean_data = data["PL"].mean()
PW_mean_data = data["PW"].mean()

print("SL mean:",SL_mean_data, "\nSW Mean:", SW_mean_data, "\nPL mean:",PL_mean_data, "\nPL mean:",PL_mean_data)
# Out:
# SL mean: 5.843333333333334
# SW Mean: 3.0540000000000003
# PL mean: 3.758666666666666
# PL mean: 3.758666666666666

# %%
###checking for null values

data.isnull()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
data.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %%
### visualisations

# %%
plt.figure(figsize=(8,6))


plt.subplot(2,1,1)
plt.scatter (data['SL'], data['PL'], s=18, c='red')
plt.title('SL vs PL')
plt.xlabel('SL')
plt.ylabel('PL')


plt.subplot(2,1,2)
plt.scatter (data['SW'], data[ 'PW'], s=20, c='blue')
plt.title('SW vs PW')
plt.xlabel('SW')
plt.ylabel('PW')
plt.tight_layout()

# %%
data.plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
data.plot(kind="line")
# Out:
# <AxesSubplot:>

# %%
g = sns.pairplot(data,hue="Classification")
